# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import snowflake.connector

# %%
conn = snowflake.connector.connect(
user = "EMADAM",
password = "Emad646261." ,
account = "MRVLRCM-BA89847" ,
database = "python_assessment" ,
schema = "python_assessment"
)

cur = conn.cursor()
cur.execute('select * from "spotify_song"')

df = cur.fetch_pandas_all()

conn.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262670 entries, 0 to 262669
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   track_id                  262664 non-null  object
#  1   track_name                262664 non-null  object
#  2   track_artist              262664 non-null  object
#  3   track_popularity          262664 non-null  float64
#  4   track_album_id            262664 non-null  object
#  5   track_album_name          262664 non-null  object
#  6   track_album_release_date  224148 non-null  float64
#  7   playlist_name             262664 non-null  object
#  8   playlist_id               262664 non-null  object
#  9   playlist_genre            262664 non-null  object
#  10  playlist_subgenre         262664 non-null  object
#  11  danceability              262664 non-null  float64
#  12  energy                    262664 non-null  float64
#  13  key                       262664 non-null  float64
#  14  loudness                  262664 non-null  float64
#  15  mode                      262664 non-null  float64
#  16  speechiness               262664 non-null  float64
#  17  acousticness              262664 non-null  float64
#  18  instrumentalness          262664 non-null  float64
#  19  liveness                  262664 non-null  float64
#  20  valence                   262664 non-null  float64
#  21  tempo                     262664 non-null  float64
#  22  duration_ms               262664 non-null  float64
#  23  duration_min              164165 non-null  float64
# dtypes: float64(15), object(9)
# memory usage: 48.1+ MB

# %%
# What are the top 5 most popular artists?
# Show a bar chart of the top 5 artists by average popularity

# %%
top_artists = df.groupby('track_artist')['track_popularity'].mean().sort_values(ascending=False).head(5)
print(top_artists)
# Out:
# track_artist
# Trevor Daniel    97.000000
# Y2K              91.000000
# Don Toliver      90.714286
# Roddy Ricch      88.210526
# DaBaby           87.857143
# Name: track_popularity, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=top_artists.index, y=top_artists.values, palette='viridis', orient='v')
plt.title('Top 5 Artists by Average Popularity')
plt.xlabel('Artist')
plt.ylabel('Average Popularity')
plt.show()

# %%
# What genres are the top 5 most popular artists working in?
#Show a pie chart showing the split of genres of tracks produced
#by the top 5 artist (25% pop, 40% EDM etc.)


# Find the top 5 most popular artists
top_artists = df.groupby('track_artist')['track_popularity'].mean().nlargest(5).index

# Filter the DataFrame for tracks by the top 5 artists
top_tracks = df[df['track_artist'].isin(top_artists)]

# Get the count of tracks in each genre
genre_counts = top_tracks['playlist_genre'].value_counts()

print(genre_counts)
# Out:
# playlist_genre
# rap      192
# r&b      104
# latin     56
# edm       48
# pop       24
# Name: count, dtype: int64

# %%
# What genres are the top 5 most popular artists working in?
#Show a pie chart showing the split of genres of tracks produced
#by the top 5 artist (25% pop, 40% EDM etc.)

# Choose a different Seaborn color palette
custom_palette = sns.color_palette('Set3')

# Plot a pie chart with a custom Seaborn color palette
plt.figure(figsize=(10, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=140, colors=custom_palette)
plt.title('Genre Split of Tracks by Top 5 Artists')
plt.show()

# %%
#Are songs getting shorter?
#Show a plot showing average duration by year

# Extract the year from the release date
#df['release_year'] = pd.to_datetime(df['track_album_release_date']).dt.year


# Plot average duration by year
average_duration_by_year = df.groupby('track_album_release_date')['duration_ms'].mean()

plt.figure(figsize=(14, 8))
sns.lineplot(x=average_duration_by_year.index, y=average_duration_by_year.values, marker='o', color='blue')
plt.title('Average Duration of Songs by Year')
plt.xlabel('Year')
plt.ylabel('Average Duration (ms)')
plt.show()
#print(average_duration_by_year)
print(df['release_year'] )
# Out:
# 0         1970.0
# 1         1970.0
# 2         1970.0
# 3         1970.0
# 4         1970.0
#            ...
# 262665    1970.0
# 262666    1970.0
# 262667    1970.0
# 262668    1970.0
# 262669    1970.0
# Name: release_year, Length: 262670, dtype: float64

# %%
#How has genres evolved over time?
#Show a plot showing count of songs within a genre each year


# Extract the year from the release date
df['release_year'] = pd.to_datetime(df['track_album_release_date']).dt.year

# Plot count of songs within each genre for each year
sns.countplot(x='release_year', hue='playlist_genre', data=df)
plt.title('Count of Songs Within Each Genre Over Time')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Genre', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Group by genre and calculate the average danceability for each genre
average_danceability = df.groupby('playlist_genre')['danceability'].mean()

# Get the top 5 most danceable genres
top_danceable_genres = average_danceability.nlargest(5)
print(top_danceable_genres)
# Out:
# playlist_genre
# rap      0.718353
# latin    0.713287
# r&b      0.670179
# edm      0.655041
# pop      0.639302
# Name: danceability, dtype: float64

# %%
# Plot a vertical bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=top_danceable_genres.index, y=top_danceable_genres.values, palette='viridis')
plt.title('Top 5 Most Danceable Genres on Average')
plt.xlabel('Genre')
plt.ylabel('Average Danceability')
plt.show()

# %%
df
# Out:
#                       track_id  \
# 0       6f807x0ima9a1j3VPbc7VN
# 1       0r7CVbZTWZgbTCYdfa2P31
# 2       1z1Hg7Vb0AhHDiEmnDE79l
# 3       75FpbthrwQmzHlBJLuGdC7
# 4       1e8PAfcKUYoKkxPhrHqw4x
# ...                        ...
# 262665  7bxnKAamR3snQ1VGLuVfC1
# 262666  5Aevni09Em4575077nkWHz
# 262667  7ImMqPP3Q1yfUHvsdn7wEo
# 262668  2m69mhnfQ1Oq6lGtXuYhgX
# 262669  29zWqhca3zt5NsckZqDf6c
#
#                                                track_name      track_artist  \
# 0       I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                         Memories - Dillon Francis Remix          Maroon 5
# 2                         All the Time - Don Diablo Remix      Zara Larsson
# 3                       Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                 Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                   ...               ...
# 262665               City Of Lights - Official Radio Edit      Lush & Simon
# 262666                Closer - Sultan & Ned Shepard Remix    Tegan and Sara
# 262667                       Sweet Surrender - Radio Edit       Starkillers
# 262668                     Only For You - Maor Levi Remix            Mat Zo
# 262669                             Typhoon - Original Mix      Julian Calor
#
#         track_popularity          track_album_id  \
# 0                   66.0  2oCs0DGTsRO98Gh5ZSl2Cx
# 1                   67.0  63rPSO264uRjW1X5E6cWv6
# 2                   70.0  1HoSmj2eLcsrR0vE9gThr4
# 3                   60.0  1nqYsOef1yKKuGOVchbsk6
# 4                   69.0  7m7vv9wlQ4i0LFuJiE2zsQ
# ...                  ...                     ...
# 262665              42.0  2azRoBBWEEEYhqV6sb7JrT
# 262666              20.0  6kD6KLxj7s8eCE3ABvAyf5
# 262667              14.0  0ltWNSY9JgxoIZO4VzuCa6
# 262668              15.0  1fGrOkHnHJcStl14zNx8Jy
# 262669              27.0  0X3mUOm6MhxR7PzxG95rAo
#
#                                          track_album_name  \
# 0       I Don't Care (with Justin Bieber) [Loud Luxury...
# 1                         Memories (Dillon Francis Remix)
# 2                         All the Time (Don Diablo Remix)
# 3                             Call You Mine - The Remixes
# 4                 Someone You Loved (Future Humans Remix)
# ...                                                   ...
# 262665                         City Of Lights (Vocal Mix)
# 262666                                     Closer Remixed
# 262667                       Sweet Surrender (Radio Edit)
# 262668                             Only For You (Remixes)
# 262669                                      Typhoon/Storm
#
#         track_album_release_date    playlist_name             playlist_id  \
# 0                   1.560470e+15        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 1                   1.576195e+15        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 2                   1.562285e+15        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 3                   1.563494e+15        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 4                   1.551744e+15        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# ...                          ...              ...                     ...
# 262665              1.398643e+15  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 262666              1.362701e+15  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 262667              1.398038e+15  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 262668              1.388534e+15  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 262669              1.393805e+15  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
#
#        playlist_genre  ... mode  speechiness  acousticness  instrumentalness  \
# 0                 pop  ...  1.0       0.0583      0.102000          0.000000
# 1                 pop  ...  1.0       0.0373      0.072400          0.004210
# 2                 pop  ...  0.0       0.0742      0.079400          0.000023
# 3                 pop  ...  1.0       0.1020      0.028700          0.000009
# 4                 pop  ...  1.0       0.0359      0.080300          0.000000
# ...               ...  ...  ...          ...           ...               ...
# 262665            edm  ...  1.0       0.0936      0.076600          0.000000
# 262666            edm  ...  1.0       0.0420      0.001710          0.004270
# 262667            edm  ...  0.0       0.0481      0.108000          0.000001
# 262668            edm  ...  1.0       0.1090      0.007920          0.127000
# 262669            edm  ...  0.0       0.0385      0.000133          0.341000
#
#         liveness  valence    tempo  duration_ms  duration_min  release_year
# 0         0.0653   0.5180  122.036     194754.0      3.245900        1970.0
# 1         0.3570   0.6930   99.972     162600.0      2.710000        1970.0
# 2         0.1100   0.6130  124.008     176616.0      2.943600        1970.0
# 3         0.2040   0.2770  121.956     169093.0      2.818217        1970.0
# 4         0.0833   0.7250  123.976     189052.0      3.150867        1970.0
# ...          ...      ...      ...          ...           ...           ...
# 262665    0.0668   0.2100  128.170     204375.0      3.406250        1970.0
# 262666    0.3750   0.4000  128.041     353120.0      5.885333        1970.0
# 262667    0.1500   0.4360  127.989     210112.0      3.501867        1970.0
# 262668    0.3430   0.3080  128.008     367432.0      6.123867        1970.0
# 262669    0.7420   0.0894  127.984     337500.0      5.625000        1970.0
#
# [262670 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# track_id                        6
# track_name                      6
# track_artist                    6
# track_popularity                6
# track_album_id                  6
# track_album_name                6
# track_album_release_date    38522
# playlist_name                   6
# playlist_id                     6
# playlist_genre                  6
# playlist_subgenre               6
# danceability                    6
# energy                          6
# key                             6
# loudness                        6
# mode                            6
# speechiness                     6
# acousticness                    6
# instrumentalness                6
# liveness                        6
# valence                         6
# tempo                           6
# duration_ms                     6
# duration_min                98505
# release_year                38522
# dtype: int64
